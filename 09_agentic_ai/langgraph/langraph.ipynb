# %%
import sys
print(sys.executable)
# Out:
# C:\Users\SHARJEELAHMED\Desktop\data-science\.venv\Scripts\python.exe

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 3.0.2

# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.4.4

# %%
# langgraph
