# %%
from langgraph.graph import StateGraph , START , END
from langchain_mistralai import ChatMistralAI
from typing import TypedDict

from dotenv import load_dotenv
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langgraph.graph import StateGraph , START , END
#       2 from langchain_mistralai import ChatMistralAI
#       3 from typing import TypedDict
#       4
#
# ModuleNotFoundError: No module named 'langgraph'

# %%
model = ChatMistralAI(model="")

# %%
class Human(TypeError):
    name : str
    age : int

# %%
state = StateGraph(Human)

# %%
def bmi(state : int) -> Human:
    pass

# %%
state.add_node("human" , bmi)

# %%
state.add_edge("bmi" , END)

# %%
a = 10

# %% [raw]
# print(a)

# %%
a
# Out:
# 10
